# %%
import matplotlib.pyplot as plt
import sympy as sp
from functions import graph_from_slope_intercept
# From Python Data Science Tools

x = sp.symbols('x')
f = 3*x + 2

x_vals, y_vals = graph_from_slope_intercept(3, 2)
plt.plot(x_vals, y_vals)

limit_value = sp.limit(f, x, 4)
print("Limit value: ", limit_value) #=> 14
# Out:
# Limit value:  14
